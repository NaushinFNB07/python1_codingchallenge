# %%
student_list={'priya':'grade A',
              'brindha':'grade B',
              'chitra':'grade c',
              'devi':'grade D'}
print(student_list)
student_list.update({'anu':'grade c','balu':'grade A','velu':'grade B'})
print(student_list)
hobbies=input('enter your hobbies:')
print(hobbies)
frozen_hobbies=frozenset(hobbies)
print(frozen_hobbies)

# Fix: Access the value for 'priya' using its key
print(student_list['priya'])
print(student_list['balu'])
print(student_list['anu'])
# Out:
# {'priya': 'grade A', 'brindha': 'grade B', 'chitra': 'grade c', 'devi': 'grade D'}
# {'priya': 'grade A', 'brindha': 'grade B', 'chitra': 'grade c', 'devi': 'grade D', 'anu': 'grade c', 'balu': 'grade A', 'velu': 'grade B'}
# enter your hobbies:playing
# playing
# frozenset({'n', 'l', 'a', 'i', 'p', 'y', 'g'})
# grade A
# grade A
# grade c
