# %%
employees=[["anu","9356782120","anu@gmail.com"],["priya","9765372184","priya@gmail.com"],
["chitra","9543987231","chitra@gmail.com"]]
print(employees)
name=input(" enter the name:")
phone=input("enter the phone number:")
email_id=input("enter the email id:")
new_contact=[name,phone,email_id]
employees.append(new_contact)
print(employees)
removed_contact=employees.pop()
print(removed_contact)
print(employees)
employees.sort()
print(employees)
# Out:
# [['anu', '9356782120', 'anu@gmail.com'], ['priya', '9765372184', 'priya@gmail.com'], ['chitra', '9543987231', 'chitra@gmail.com']]
#  enter the name:divya
# enter the phone number:987654321
# enter the email id:divya@gmail.com
# [['anu', '9356782120', 'anu@gmail.com'], ['priya', '9765372184', 'priya@gmail.com'], ['chitra', '9543987231', 'chitra@gmail.com'], ['divya', '987654321', 'divya@gmail.com']]
# ['divya', '987654321', 'divya@gmail.com']
# [['anu', '9356782120', 'anu@gmail.com'], ['priya', '9765372184', 'priya@gmail.com'], ['chitra', '9543987231', 'chitra@gmail.com']]
# [['anu', '9356782120', 'anu@gmail.com'], ['chitra', '9543987231', 'chitra@gmail.com'], ['priya', '9765372184', 'priya@gmail.com']]
