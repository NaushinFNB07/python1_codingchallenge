# %%
categories=("Electronics","stationery","clothing")
products=("laptop","pen","shirt")
new=("mobile","pencil","pant")
new_product=new+products
print(new_product)
product_1=input("enter new product:")
print(product_1)
final_product=new_product+(product_1,)
print(final_product)
remove_product=input("enter product index to remove:")
print(remove_product)
final_product=list(final_product)
final_product.pop(3)
print(final_product)
print(categories)
# Out:
# ('mobile', 'pencil', 'pant', 'laptop', 'pen', 'shirt')
# enter new product:jeans
# jeans
# ('mobile', 'pencil', 'pant', 'laptop', 'pen', 'shirt', 'jeans')
# enter product index to remove:3
# 3
# ['mobile', 'pencil', 'pant', 'pen', 'shirt', 'jeans']
# ('Electronics', 'stationery', 'clothing')

# %%
for item in tuple:
  print(item)
