# %%
string2="feedback analyzer helps to analyze data in which fields data has been entered in your stored data"
print(string2)
count_words=len(string2.split())
print(count_words)
count1=string2.count('data')
print(count1)
print(string2[0:5])
print(string2[-5:])
print(string2[::-1])
# Out:
# feedback analyzer helps to analyze data in which fields data has been entered in your stored data
# 17
# 3
# feedb
#  data
# atad derots ruoy ni deretne neeb sah atad sdleif hcihw ni atad ezylana ot spleh rezylana kcabdeef
