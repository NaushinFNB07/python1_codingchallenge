# %%
exam_score=[67,56,75,80,90,92,93,86,85,55]
print("exam scores:",exam_score)
for index, current_score in enumerate(exam_score):
    print(index, ':', current_score)
high_scores=[]
for current_score in exam_score:
    if current_score > 75:
        high_scores.append(current_score)
        print("scores greater than 75:",high_scores)
average=total/len(exam_score)
print("average score:",average)
# Out:
# exam scores: [67, 56, 75, 80, 90, 92, 93, 86, 85, 55]
# 0 : 67
# 1 : 56
# 2 : 75
# 3 : 80
# 4 : 90
# 5 : 92
# 6 : 93
# 7 : 86
# 8 : 85
# 9 : 55
# scores greater than 75: [80]
# scores greater than 75: [80, 90]
# scores greater than 75: [80, 90, 92]
# scores greater than 75: [80, 90, 92, 93]
# scores greater than 75: [80, 90, 92, 93, 86]
# scores greater than 75: [80, 90, 92, 93, 86, 85]
# average score: 77.9
